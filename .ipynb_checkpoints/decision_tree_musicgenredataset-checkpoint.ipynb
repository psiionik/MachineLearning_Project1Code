# %%
import numpy as np
import struct
from array import array
import pandas as pd
import os
from os.path  import join
import random as rn
from sklearn import tree
import graphviz
import pydotplus
from IPython.display import Image
from io import StringIO
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import StratifiedKFold
from yellowbrick.model_selection import LearningCurve
from sklearn.model_selection import learning_curve
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import random
import matplotlib.pyplot as plt
import time

# %%
"""
Loading in the dataset into a pandas dataframe object.

For the following segments the code snippets were retreved from: https://www.kaggle.com/code/anetakovacheva/interpreting-a-music-genre-classifier
"""

# %matplotlib inline

input_path = 'data/musicgenre_datafolder'
file_path = join(input_path, 'music_genre.csv')

music_data = pd.read_csv(file_path)

# %%
"""
Cleaning and Pre-Processing all of the data
"""

"""
There are some duplicated data that needs to be cleaned up
"""
music_data.duplicated().any()
duplicated = music_data.duplicated()
music_data[duplicated]
music_data.iloc[9999:10006]
music_data.drop([10000, 10001, 10002, 10003, 10004], inplace = True)

"""
Removing some columns that don't matter or will complicated the training too much
"""
music_data.reset_index(inplace = True)
music_data = music_data.drop(["artist_name", "index", "instance_id", "track_name", "obtained_date"], axis = 1)

"""
Normalizing the music data such that it removes invalid values for 'tempo' and converts
the column values into a float
"""
music_data = music_data.drop(music_data[music_data["tempo"] == "?"].index)
music_data["tempo"] = music_data["tempo"].astype("float")
music_data["tempo"] = np.around(music_data["tempo"], decimals = 2)

"""
Encoding the columns that are strings with LabelEncoder since this will mess
up the algorithms that require numeric values
"""
key_encoder = LabelEncoder()
mode_encoder = LabelEncoder()
music_data["key"] = key_encoder.fit_transform(music_data["key"])
music_data["mode"] = mode_encoder.fit_transform(music_data["mode"])

"""
Separating out the column features from the music genre label
"""
music_features = music_data.drop("music_genre", axis = 1)
music_labels = music_data["music_genre"]

"""
Scaling the features out into a scale centered around 0 with a standard deviation of 1
"""
scaler = StandardScaler()
music_features_scaled = scaler.fit_transform(music_features)

# %%
"""
Splitting the data into Training and Testing Data Sets
"""
train_features, test_features, train_labels, test_labels = train_test_split(
    music_features_scaled, music_labels, test_size = 0.1, stratify = music_labels)

# %%
"""
Setting up seed values for reproducability
"""
seed = 1234
np.random.seed(seed)
rn.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)

# %%
"""
Getting the size values for the training and testing dataset
"""
size_train_samples = np.shape(train_features)[0]
size_test_samples = np.shape(test_features)[0]

# %%
"""
This is to split up the data into sets where the size of the training data across iterations
increases by a certain percentage.
This is to prep the data for the Learning Curve Visualization
"""
learning_percentages_train_list = []
learning_percentages_label_list = []
for i in (np.logspace(-1, 1.0, 20, base=10.0) / 10):
    random_indexes = np.random.choice(size_train_samples, int(i * size_train_samples), replace = False)
    learning_percentages_train_list.append(np.take(train_features, random_indexes, axis=0))
    learning_percentages_label_list.append(np.take(train_labels, random_indexes))

# %%
"""
Actually training the Decision Tree Classifier to generate the graph for the learning graph visualizer.
This should utilize the percentage of samples lists that use randomly selected samples of the
overall training data. This is so that we can test the accuracy (using cross-validation) across different
training data size samples to see at what point the accuracy score stops being affected by the size of the training
samples. This is also to see at what point the data might start getting overfit.
"""
# Defining hyperparameters here
max_depth = None
max_leaf_nodes = None
min_samples_split = 2
criterion = "entropy"

# lists to hold the results of training / validation scores
x_axis_list = []
avg_train_scores_list = []
avg_validation_scores_list = []

# First declaring the Decision Tree Classifer from scikit-learn
clf = tree.DecisionTreeClassifier(
    criterion=criterion,
    max_depth=max_depth,
    random_state=seed
)

# Main loop for the training based on different training sample sizes
for i in range(0, len(learning_percentages_train_list)):
    scores = cross_validate(
        clf,
        learning_percentages_train_list[i],
        learning_percentages_label_list[i],
        scoring="f1_weighted",
        return_train_score=True,
        cv=5,
        n_jobs=10,
    )
    
    avg_train_scores = np.average(scores['train_score'])
    avg_validation_scores = np.average(scores['test_score'])
    
    x_axis_list.append(len(learning_percentages_train_list[i]))
    avg_train_scores_list.append(avg_train_scores)
    avg_validation_scores_list.append(avg_validation_scores)
    
    print("=============================================")
    print("Run for " + str(len(learning_percentages_train_list[i])) + " size")
    print("Average Training Score: " + str(avg_train_scores))
    print("Average Validation Score: " + str(avg_validation_scores))
    print("=============================================")
# Out:
# =============================================
# Run for 405 size
# Average Training Score: 1.0
# Average Validation Score: 0.36003683333549275
# =============================================
# =============================================
# Run for 516 size
# Average Training Score: 1.0
# Average Validation Score: 0.3891992013685309
# =============================================
# =============================================
# Run for 657 size
# Average Training Score: 0.9988589252018475
# Average Validation Score: 0.3711668843211521
# =============================================
# =============================================
# Run for 838 size
# Average Training Score: 0.9988049544570858
# Average Validation Score: 0.38403351661804735
# =============================================
# =============================================
# Run for 1068 size
# Average Training Score: 1.0
# Average Validation Score: 0.38755511172448853
# =============================================
# =============================================
# Run for 1361 size
# Average Training Score: 0.9994487273822861
# Average Validation Score: 0.39654044154605594
# =============================================
# =============================================
# Run for 1734 size
# Average Training Score: 0.9975483600447635
# Average Validation Score: 0.39467952360560765
# =============================================
# =============================================
# Run for 2210 size
# Average Training Score: 0.9993205846431537
# Average Validation Score: 0.4186094833108157
# =============================================
# =============================================
# Run for 2816 size
# Average Training Score: 0.9980463200425991
# Average Validation Score: 0.42281970031992244
# =============================================
# =============================================
# Run for 3589 size
# Average Training Score: 0.9977710149344045
# Average Validation Score: 0.41692009170829686
# =============================================
# =============================================
# Run for 4573 size
# Average Training Score: 0.997265958107271
# Average Validation Score: 0.4144920242514122
# =============================================
# =============================================
# Run for 5828 size
# Average Training Score: 0.9958397173724624
# Average Validation Score: 0.4331093416107719
# =============================================
# =============================================
# Run for 7426 size
# Average Training Score: 0.9940001692360019
# Average Validation Score: 0.4337353864009814
# =============================================
# =============================================
# Run for 9463 size
# Average Training Score: 0.9935516312037098
# Average Validation Score: 0.43015734280584017
# =============================================
# =============================================
# Run for 12059 size
# Average Training Score: 0.9914348605992981
# Average Validation Score: 0.4316745258324759
# =============================================
# =============================================
# Run for 15367 size
# Average Training Score: 0.9899203810289745
# Average Validation Score: 0.44568235111073157
# =============================================
# =============================================
# Run for 19582 size
# Average Training Score: 0.9875478740019286
# Average Validation Score: 0.44405472209483376
# =============================================
# =============================================
# Run for 24952 size
# Average Training Score: 0.9837402077871985
# Average Validation Score: 0.44248207885717594
# =============================================
# =============================================
# Run for 31796 size
# Average Training Score: 0.9794989417516934
# Average Validation Score: 0.4398141052116854
# =============================================
# =============================================
# Run for 40518 size
# Average Training Score: 0.9739713550171472
# Average Validation Score: 0.43879658474942074
# =============================================

# %%
"""
Plotting the results into a learning curve graph
"""

# Plotting the training scores
plt.plot(
    x_axis_list,
    avg_train_scores_list,
    color="red",
    linewidth=3,
    marker='o',
    label = "Average Training Scores"
)

# Plotting the validation scores
plt.plot(
    x_axis_list,
    avg_validation_scores_list,
    color="orange",
    linewidth=3,
    marker='o',
    label = "Average Validation Scores"
)

# Naming X-Axis
plt.xlabel('Dataset Sizes')
# Naming Y-Axis
plt.ylabel('F1_weighted scores as a percentage')
# Naming Title
plt.title("Learning Curve Graph using Cross-Validation on Music Genre Dataset: Decision Trees")

plt.legend()

plt.show()

# %%
"""
Training the Decision Tree based off of the first Hyperparameter: max_depth
Building a validation curve out of this to see how the hyperparameter affects the training.
"""
# Defining hyperparameters here
max_leaf_nodes = None
min_samples_split = 2
criterion = "entropy"
max_depth_lower_limit = 1
max_depth_upper_limit = 25 # It seems that around 15, the model doesn't get better

# lists to hold the results of training / validation scores
x_axis_list = []
avg_train_scores_list = []
avg_validation_scores_list = []

# Main loop for the training based on different training sample sizes
for i in range(max_depth_lower_limit, max_depth_upper_limit + 1):
    # First declaring the Decision Tree Classifer from scikit-learn
    clf = tree.DecisionTreeClassifier(
        criterion=criterion,
        max_depth=i,
        random_state=seed
    )
    
    scores = cross_validate(
        clf,
        train_features,
        train_labels,
        scoring="accuracy",
        return_train_score=True,
        cv=5,
        n_jobs=4,
    )
    
    avg_train_scores = np.average(scores['train_score'])
    avg_validation_scores = np.average(scores['test_score'])
    
    x_axis_list.append(i)
    avg_train_scores_list.append(avg_train_scores)
    avg_validation_scores_list.append(avg_validation_scores)
    
    print("=============================================")
    print("Run for " + str(i) + " max_depth")
    print("Average Training Score: " + str(avg_train_scores))
    print("Average Validation Score: " + str(avg_validation_scores))
    print("=============================================")
# Out:
# =============================================
# Run for 1 max_depth
# Average Training Score: 0.19838096668162528
# Average Validation Score: 0.19838096964562502
# =============================================
# =============================================
# Run for 2 max_depth
# Average Training Score: 0.32628091290889255
# Average Validation Score: 0.32622539712358367
# =============================================
# =============================================
# Run for 3 max_depth
# Average Training Score: 0.3792018232115222
# Average Validation Score: 0.37889330289599393
# =============================================
# =============================================
# Run for 4 max_depth
# Average Training Score: 0.43183274983175257
# Average Validation Score: 0.43025305424154625
# =============================================
# =============================================
# Run for 5 max_depth
# Average Training Score: 0.4576484139651648
# Average Validation Score: 0.45434126806897235
# =============================================
# =============================================
# Run for 6 max_depth
# Average Training Score: 0.4917876143900702
# Average Validation Score: 0.4819088734030112
# =============================================
# =============================================
# Run for 7 max_depth
# Average Training Score: 0.5186768978286957
# Average Validation Score: 0.4999504619631329
# =============================================
# =============================================
# Run for 8 max_depth
# Average Training Score: 0.5433017563789223
# Average Validation Score: 0.5138702635210364
# =============================================
# =============================================
# Run for 9 max_depth
# Average Training Score: 0.5708203676176548
# Average Validation Score: 0.5188804732601808
# =============================================
# =============================================
# Run for 10 max_depth
# Average Training Score: 0.6021891476310441
# Average Validation Score: 0.5205586934214097
# =============================================
# =============================================
# Run for 11 max_depth
# Average Training Score: 0.6401537885497476
# Average Validation Score: 0.5114268916037703
# =============================================
# =============================================
# Run for 12 max_depth
# Average Training Score: 0.687126752597395
# Average Validation Score: 0.5030602963644655
# =============================================
# =============================================
# Run for 13 max_depth
# Average Training Score: 0.7417259315960092
# Average Validation Score: 0.4872400433266706
# =============================================
# =============================================
# Run for 14 max_depth
# Average Training Score: 0.7988178410349194
# Average Validation Score: 0.47492459802159726
# =============================================
# =============================================
# Run for 15 max_depth
# Average Training Score: 0.8514919754292141
# Average Validation Score: 0.4652252087785361
# =============================================
# =============================================
# Run for 16 max_depth
# Average Training Score: 0.8924799175513318
# Average Validation Score: 0.45426729451597947
# =============================================
# =============================================
# Run for 17 max_depth
# Average Training Score: 0.92112150738849
# Average Validation Score: 0.44836862244602715
# =============================================
# =============================================
# Run for 18 max_depth
# Average Training Score: 0.9400205011933902
# Average Validation Score: 0.44296357338555337
# =============================================
# =============================================
# Run for 19 max_depth
# Average Training Score: 0.9516017677779918
# Average Validation Score: 0.4412607532413073
# =============================================
# =============================================
# Run for 20 max_depth
# Average Training Score: 0.9590614067018819
# Average Validation Score: 0.4379535067935182
# =============================================
# =============================================
# Run for 21 max_depth
# Average Training Score: 0.963824717927759
# Average Validation Score: 0.4389159213575365
# =============================================
# =============================================
# Run for 22 max_depth
# Average Training Score: 0.966693813716403
# Average Validation Score: 0.4359296899165592
# =============================================
# =============================================
# Run for 23 max_depth
# Average Training Score: 0.9689273871668445
# Average Validation Score: 0.4379780367258223
# =============================================
# =============================================
# Run for 24 max_depth
# Average Training Score: 0.9703650232886213
# Average Validation Score: 0.4365958843805062
# =============================================
# =============================================
# Run for 25 max_depth
# Average Training Score: 0.9715250029406592
# Average Validation Score: 0.43617639025386257
# =============================================

# %%
"""
Plotting the results into a validation curve graph
"""

# Plotting the training scores
plt.plot(
    x_axis_list,
    avg_train_scores_list,
    color="blue",
    linewidth=3,
    marker='o',
    label = "Average Training Scores"
)

# Plotting the validation scores
plt.plot(
    x_axis_list,
    avg_validation_scores_list,
    color="purple",
    linewidth=3,
    marker='o',
    label = "Average Validation Scores"
)

# Naming X-Axis
plt.xlabel('Max_Depth')
# Naming Y-Axis
plt.ylabel('Accuracy scores as a percentage')
# Naming Title
plt.title("Validation Curve Graph using Cross-Validation on Music Genre Dataset")

plt.legend()

plt.show()

# %%
"""
Training the Decision Tree based off of the first Hyperparameter: max_leaf_nodes
Building a validation curve out of this to see how the hyperparameter affects the training.
"""
# Defining hyperparameters here
min_samples_split = 2
criterion = "entropy"
max_depth = None # It seems that around 15, the model doesn't get better
max_leaf_nodes_lower_limit = 2
max_leaf_nodes_upper_limit = 502

# lists to hold the results of training / validation scores
x_axis_list = []
avg_train_scores_list = []
avg_validation_scores_list = []

# Main loop for the training based on different training sample sizes
for i in range(max_leaf_nodes_lower_limit, max_leaf_nodes_upper_limit + 1, 10):
    # First declaring the Decision Tree Classifer from scikit-learn
    clf = tree.DecisionTreeClassifier(
        criterion=criterion,
        max_depth=max_depth,
        max_leaf_nodes=i,
        random_state=seed
    )
    
    scores = cross_validate(
        clf,
        train_features,
        train_labels,
        scoring="accuracy",
        return_train_score=True,
        cv=5,
        n_jobs=4,
    )
    
    avg_train_scores = np.average(scores['train_score'])
    avg_validation_scores = np.average(scores['test_score'])
    
    x_axis_list.append(i)
    avg_train_scores_list.append(avg_train_scores)
    avg_validation_scores_list.append(avg_validation_scores)
    
    print("=============================================")
    print("Run for " + str(i) + " max_leaf_nodes")
    print("Average Training Score: " + str(avg_train_scores))
    print("Average Validation Score: " + str(avg_validation_scores))
    print("=============================================")
# Out:
# =============================================
# Run for 2 max_leaf_nodes
# Average Training Score: 0.19838096668162528
# Average Validation Score: 0.19838096964562502
# =============================================
# =============================================
# Run for 12 max_leaf_nodes
# Average Training Score: 0.4266313570571598
# Average Validation Score: 0.42529237035653616
# =============================================
# =============================================
# Run for 22 max_leaf_nodes
# Average Training Score: 0.4517436663474793
# Average Validation Score: 0.4494789841160312
# =============================================
# =============================================
# Run for 32 max_leaf_nodes
# Average Training Score: 0.47253072997129414
# Average Validation Score: 0.46675525340754087
# =============================================
# =============================================
# Run for 42 max_leaf_nodes
# Average Training Score: 0.485987710229052
# Average Validation Score: 0.4778861624745274
# =============================================
# =============================================
# Run for 52 max_leaf_nodes
# Average Training Score: 0.4948418056723547
# Average Validation Score: 0.48462383802618286
# =============================================
# =============================================
# Run for 62 max_leaf_nodes
# Average Training Score: 0.5018448633772952
# Average Validation Score: 0.49005350229808975
# =============================================
# =============================================
# Run for 72 max_leaf_nodes
# Average Training Score: 0.5093538673048775
# Average Validation Score: 0.49550794320263813
# =============================================
# =============================================
# Run for 82 max_leaf_nodes
# Average Training Score: 0.5149871625083857
# Average Validation Score: 0.5000985735360102
# =============================================
# =============================================
# Run for 92 max_leaf_nodes
# Average Training Score: 0.5201576882363765
# Average Validation Score: 0.502665435723354
# =============================================
# =============================================
# Run for 102 max_leaf_nodes
# Average Training Score: 0.5244212274103296
# Average Validation Score: 0.505232179129054
# =============================================
# =============================================
# Run for 112 max_leaf_nodes
# Average Training Score: 0.5284934952067804
# Average Validation Score: 0.507206549339641
# =============================================
# =============================================
# Run for 122 max_leaf_nodes
# Average Training Score: 0.5312885491051912
# Average Validation Score: 0.5082431080149102
# =============================================
# =============================================
# Run for 132 max_leaf_nodes
# Average Training Score: 0.5337380660609428
# Average Validation Score: 0.5097239130839991
# =============================================
# =============================================
# Run for 142 max_leaf_nodes
# Average Training Score: 0.5363603634800315
# Average Validation Score: 0.5114268245987403
# =============================================
# =============================================
# Run for 152 max_leaf_nodes
# Average Training Score: 0.5387790491748543
# Average Validation Score: 0.5128335860641233
# =============================================
# =============================================
# Run for 162 max_leaf_nodes
# Average Training Score: 0.5412902712907124
# Average Validation Score: 0.5147833593373763
# =============================================
# =============================================
# Run for 172 max_leaf_nodes
# Average Training Score: 0.5444123380968348
# Average Validation Score: 0.5167577600047951
# =============================================
# =============================================
# Run for 182 max_leaf_nodes
# Average Training Score: 0.5464608137694438
# Average Validation Score: 0.5180904991862544
# =============================================
# =============================================
# Run for 192 max_leaf_nodes
# Average Training Score: 0.5483735378233293
# Average Validation Score: 0.5189790528875574
# =============================================
# =============================================
# Run for 202 max_leaf_nodes
# Average Training Score: 0.5499901082117832
# Average Validation Score: 0.5197687954895625
# =============================================
# =============================================
# Run for 212 max_leaf_nodes
# Average Training Score: 0.5515634862444678
# Average Validation Score: 0.5205832568562287
# =============================================
# =============================================
# Run for 222 max_leaf_nodes
# Average Training Score: 0.5536119628688236
# Average Validation Score: 0.5213483446529195
# =============================================
# =============================================
# Run for 232 max_leaf_nodes
# Average Training Score: 0.5555678796591769
# Average Validation Score: 0.5223109571863442
# =============================================
# =============================================
# Run for 242 max_leaf_nodes
# Average Training Score: 0.5575546535979672
# Average Validation Score: 0.5235696679925136
# =============================================
# =============================================
# Run for 252 max_leaf_nodes
# Average Training Score: 0.559257603368178
# Average Validation Score: 0.5233474884504647
# =============================================
# =============================================
# Run for 262 max_leaf_nodes
# Average Training Score: 0.5610716160689131
# Average Validation Score: 0.5241126006126209
# =============================================
# =============================================
# Run for 272 max_leaf_nodes
# Average Training Score: 0.5627807266853888
# Average Validation Score: 0.5246309027928793
# =============================================
# =============================================
# Run for 282 max_leaf_nodes
# Average Training Score: 0.5641628312467288
# Average Validation Score: 0.5240879092591083
# =============================================
# =============================================
# Run for 292 max_leaf_nodes
# Average Training Score: 0.565514086463954
# Average Validation Score: 0.524853033603997
# =============================================
# =============================================
# Run for 302 max_leaf_nodes
# Average Training Score: 0.5670936274367462
# Average Validation Score: 0.5253960362748176
# =============================================
# =============================================
# Run for 312 max_leaf_nodes
# Average Training Score: 0.5680746735835042
# Average Validation Score: 0.5258156156805901
# =============================================
# =============================================
# Run for 322 max_leaf_nodes
# Average Training Score: 0.5690125256613494
# Average Validation Score: 0.5261118144608793
# =============================================
# =============================================
# Run for 332 max_leaf_nodes
# Average Training Score: 0.5703082451304525
# Average Validation Score: 0.5260871505185153
# =============================================
# =============================================
# Run for 342 max_leaf_nodes
# Average Training Score: 0.5711473757666331
# Average Validation Score: 0.5261612032592707
# =============================================
# =============================================
# Run for 352 max_leaf_nodes
# Average Training Score: 0.5725233055862075
# Average Validation Score: 0.5262846265243187
# =============================================
# =============================================
# Run for 362 max_leaf_nodes
# Average Training Score: 0.5735290349010342
# Average Validation Score: 0.525963788167131
# =============================================
# =============================================
# Run for 372 max_leaf_nodes
# Average Training Score: 0.5743496574916103
# Average Validation Score: 0.5261365362712236
# =============================================
# =============================================
# Run for 382 max_leaf_nodes
# Average Training Score: 0.5754417625715569
# Average Validation Score: 0.5267041724275764
# =============================================
# =============================================
# Run for 392 max_leaf_nodes
# Average Training Score: 0.5765708886917948
# Average Validation Score: 0.5268522596349883
# =============================================
# =============================================
# Run for 402 max_leaf_nodes
# Average Training Score: 0.5774285370813954
# Average Validation Score: 0.5267041907016754
# =============================================
# =============================================
# Run for 412 max_leaf_nodes
# Average Training Score: 0.5787612810170775
# Average Validation Score: 0.527395231848977
# =============================================
# =============================================
# Run for 422 max_leaf_nodes
# Average Training Score: 0.5799089207030502
# Average Validation Score: 0.5274199445222717
# =============================================
# =============================================
# Run for 432 max_leaf_nodes
# Average Training Score: 0.5809084788927488
# Average Validation Score: 0.5278641817790419
# =============================================
# =============================================
# Run for 442 max_leaf_nodes
# Average Training Score: 0.5820746241497845
# Average Validation Score: 0.5275926987177308
# =============================================
# =============================================
# Run for 452 max_leaf_nodes
# Average Training Score: 0.5829014144392012
# Average Validation Score: 0.5277161006629965
# =============================================
# =============================================
# Run for 462 max_leaf_nodes
# Average Training Score: 0.5839564998113019
# Average Validation Score: 0.5285799264625888
# =============================================
# =============================================
# Run for 472 max_leaf_nodes
# Average Training Score: 0.584882013065178
# Average Validation Score: 0.5282343388839081
# =============================================
# =============================================
# Run for 482 max_leaf_nodes
# Average Training Score: 0.5861839036594095
# Average Validation Score: 0.5281355978353233
# =============================================
# =============================================
# Run for 492 max_leaf_nodes
# Average Training Score: 0.587090904679996
# Average Validation Score: 0.5279628558225969
# =============================================
# =============================================
# Run for 502 max_leaf_nodes
# Average Training Score: 0.5878374874741816
# Average Validation Score: 0.5274939363493637
# =============================================

# %%
"""
Plotting the results into a validation curve graph
"""

# Plotting the training scores
plt.plot(
    x_axis_list,
    avg_train_scores_list,
    color="blue",
    linewidth=3,
    marker='o',
    label = "Average Training Scores"
)

# Plotting the validation scores
plt.plot(
    x_axis_list,
    avg_validation_scores_list,
    color="purple",
    linewidth=3,
    marker='o',
    label = "Average Validation Scores"
)

# Naming X-Axis
plt.xlabel('Max Leaf Nodes')
# Naming Y-Axis
plt.ylabel('Accuracy scores as a percentage')
# Naming Title
plt.title("Validation Curve Graph using Cross-Validation on Music Genre Dataset")

plt.legend()

plt.show()

# %%
"""
Training the Decision Tree based off of the first Hyperparameter: max_leaf_nodes
Building a validation curve out of this to see how the hyperparameter affects the training.
"""
# Defining hyperparameters here
max_leaf_nodes = None
criterion = "entropy"
max_depth = None # It seems that around 15, the model doesn't get better
min_samples_split_lower_limit = 2
min_samples_split_upper_limit = 102

# lists to hold the results of training / validation scores
x_axis_list = []
avg_train_scores_list = []
avg_validation_scores_list = []

# Main loop for the training based on different training sample sizes
for i in range(min_samples_split_lower_limit, min_samples_split_upper_limit + 1, 5):
    # First declaring the Decision Tree Classifer from scikit-learn
    clf = tree.DecisionTreeClassifier(
        criterion=criterion,
        max_depth=max_depth,
        max_leaf_nodes=max_leaf_nodes,
        random_state=seed
    )
    
    scores = cross_validate(
        clf,
        train_features,
        train_labels,
        scoring="accuracy",
        return_train_score=True,
        cv=5,
        n_jobs=4,
    )
    
    avg_train_scores = np.average(scores['train_score'])
    avg_validation_scores = np.average(scores['test_score'])
    
    x_axis_list.append(i)
    avg_train_scores_list.append(avg_train_scores)
    avg_validation_scores_list.append(avg_validation_scores)
    
    print("=============================================")
    print("Run for " + str(i) + " max_leaf_nodes")
    print("Average Training Score: " + str(avg_train_scores))
    print("Average Validation Score: " + str(avg_validation_scores))
    print("=============================================")
# Out:
# =============================================
# Run for 2 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================
# =============================================
# Run for 7 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================
# =============================================
# Run for 12 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================
# =============================================
# Run for 17 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================
# =============================================
# Run for 22 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================
# =============================================
# Run for 27 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================
# =============================================
# Run for 32 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================
# =============================================
# Run for 37 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================
# =============================================
# Run for 42 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================
# =============================================
# Run for 47 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================
# =============================================
# Run for 52 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================
# =============================================
# Run for 57 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================
# =============================================
# Run for 62 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================
# =============================================
# Run for 67 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================
# =============================================
# Run for 72 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================
# =============================================
# Run for 77 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================
# =============================================
# Run for 82 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================
# =============================================
# Run for 87 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================
# =============================================
# Run for 92 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================
# =============================================
# Run for 97 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================
# =============================================
# Run for 102 max_leaf_nodes
# Average Training Score: 0.9740547351959643
# Average Validation Score: 0.4359543569046064
# =============================================

# %%
"""
Plotting the results into a validation curve graph
"""

# Plotting the training scores
plt.plot(
    x_axis_list,
    avg_train_scores_list,
    color="blue",
    linewidth=3,
    marker='o',
    label = "Average Training Scores"
)

# Plotting the validation scores
plt.plot(
    x_axis_list,
    avg_validation_scores_list,
    color="purple",
    linewidth=3,
    marker='o',
    label = "Average Validation Scores"
)

# Naming X-Axis
plt.xlabel('Min Samples Split')
# Naming Y-Axis
plt.ylabel('Accuracy scores as a percentage')
# Naming Title
plt.title("Validation Curve Graph using Cross-Validation on Music Genre Dataset")

plt.legend()

plt.show()

# %%
"""
Final results for the DecisionTreeClassifier using the optimized values for hyper parameters
"""
# Defining hyperparameters here
max_depth = 5
max_leaf_nodes = 300
min_samples_split = 2
criterion = "entropy"

# lists to hold the results of training / validation scores
x_axis_list = []
avg_train_scores_list = []
avg_validation_scores_list = []
iteration_wall_clock_list = []

# First declaring the Decision Tree Classifer from scikit-learn
clf = tree.DecisionTreeClassifier(
    criterion=criterion,
    max_depth=max_depth,
    random_state=seed
)

# Main loop for the training based on different training sample sizes
for i in range(0, len(learning_percentages_train_list)):
    start_time = time.time()
    scores = cross_validate(
        clf,
        learning_percentages_train_list[i],
        learning_percentages_label_list[i],
        scoring="accuracy",
        return_train_score=True,
        cv=5,
        n_jobs=10,
    )
    training_time = time.time() - start_time
    
    avg_train_scores = np.average(scores['train_score'])
    avg_validation_scores = np.average(scores['test_score'])
    
    x_axis_list.append(len(learning_percentages_train_list[i]))
    avg_train_scores_list.append(avg_train_scores)
    avg_validation_scores_list.append(avg_validation_scores)
    iteration_wall_clock_list.append(training_time)
    
    print("=============================================")
    print("Run for " + str(len(learning_percentages_train_list[i])) + " size")
    print("Average Training Score: " + str(avg_train_scores))
    print("Average Validation Score: " + str(avg_validation_scores))
    print("Training Time: " + str(training_time))
    print("=============================================")
# Out:
# =============================================
# Run for 405 size
# Average Training Score: 0.6006172839506173
# Average Validation Score: 0.35802469135802467
# Training Time: 3.5529651641845703
# =============================================
# =============================================
# Run for 516 size
# Average Training Score: 0.5818801570323703
# Average Validation Score: 0.4166542195668409
# Training Time: 0.9758830070495605
# =============================================
# =============================================
# Run for 657 size
# Average Training Score: 0.5837168205685316
# Average Validation Score: 0.3987277353689567
# Training Time: 0.061357736587524414
# =============================================
# =============================================
# Run for 838 size
# Average Training Score: 0.539086237960718
# Average Validation Score: 0.414121756487026
# Training Time: 1.0311088562011719
# =============================================
# =============================================
# Run for 1068 size
# Average Training Score: 0.5327748332580085
# Average Validation Score: 0.4278838137861437
# Training Time: 0.0660400390625
# =============================================
# =============================================
# Run for 1361 size
# Average Training Score: 0.5317766569437692
# Average Validation Score: 0.4334922430510666
# Training Time: 0.05394101142883301
# =============================================
# =============================================
# Run for 1734 size
# Average Training Score: 0.5155725561980432
# Average Validation Score: 0.4406073528676851
# Training Time: 0.07498311996459961
# =============================================
# =============================================
# Run for 2210 size
# Average Training Score: 0.5016968325791855
# Average Validation Score: 0.4398190045248869
# Training Time: 0.08110785484313965
# =============================================
# =============================================
# Run for 2816 size
# Average Training Score: 0.48126807832304114
# Average Validation Score: 0.41442374311880387
# Training Time: 0.08585095405578613
# =============================================
# =============================================
# Run for 3589 size
# Average Training Score: 0.4972139025448025
# Average Validation Score: 0.4527709467255626
# Training Time: 1.171294927597046
# =============================================
# =============================================
# Run for 4573 size
# Average Training Score: 0.4738688324556345
# Average Validation Score: 0.44019322978321435
# Training Time: 0.7990608215332031
# =============================================
# =============================================
# Run for 5828 size
# Average Training Score: 0.48498695380531115
# Average Validation Score: 0.4598490860503979
# Training Time: 0.1285400390625
# =============================================
# =============================================
# Run for 7426 size
# Average Training Score: 0.47081192330645283
# Average Validation Score: 0.45381142062164936
# Training Time: 0.1292731761932373
# =============================================
# =============================================
# Run for 9463 size
# Average Training Score: 0.4680334803228686
# Average Validation Score: 0.44911697597357125
# Training Time: 0.13299798965454102
# =============================================
# =============================================
# Run for 12059 size
# Average Training Score: 0.45687874421472674
# Average Validation Score: 0.43991954371650666
# Training Time: 0.28791189193725586
# =============================================
# =============================================
# Run for 15367 size
# Average Training Score: 0.4601906759275063
# Average Validation Score: 0.4472561299000402
# Training Time: 1.0639631748199463
# =============================================
# =============================================
# Run for 19582 size
# Average Training Score: 0.46425289993732477
# Average Validation Score: 0.4566952335528091
# Training Time: 0.3725392818450928
# =============================================
# =============================================
# Run for 24952 size
# Average Training Score: 0.45955239959680716
# Average Validation Score: 0.4501837495869318
# Training Time: 0.42293310165405273
# =============================================
# =============================================
# Run for 31796 size
# Average Training Score: 0.45919296014674343
# Average Validation Score: 0.4511259780373679
# Training Time: 0.5717098712921143
# =============================================
# =============================================
# Run for 40518 size
# Average Training Score: 0.4587405232327966
# Average Validation Score: 0.4522435872836149
# Training Time: 0.6072771549224854
# =============================================

# %%
"""
Plotting the results into a learning curve graph
"""

# Plotting the training scores
plt.plot(
    x_axis_list,
    avg_train_scores_list,
    color="red",
    linewidth=3,
    marker='o',
    label = "Average Training Scores"
)

# Plotting the validation scores
plt.plot(
    x_axis_list,
    avg_validation_scores_list,
    color="orange",
    linewidth=3,
    marker='o',
    label = "Average Validation Scores"
)

# Naming X-Axis
plt.xlabel('Dataset Sizes')
# Naming Y-Axis
plt.ylabel('F1_weighted scores as a percentage')
# Naming Title
plt.title("Learning Curve Graph using Cross-Validation on Music Genre Dataset: Decision Trees")

plt.legend()

plt.show()

# %%
"""
Plotting the results into a learning curve graph
"""

# Plotting the training scores
plt.plot(
    x_axis_list,
    iteration_wall_clock_list,
    color="red",
    linewidth=3,
    marker='o',
    label = "Average Training Scores"
)

# Naming X-Axis
plt.xlabel('Dataset Sizes')
# Naming Y-Axis
plt.ylabel('Wall Clock Times')
# Naming Title
plt.title("Performance Curve Graph using Cross-Validation on MNIST Dataset: Decision Trees")

plt.legend()

plt.show()

# %%
clf.fit(train_features, train_labels)
start_time = time.time()
score = clf.score(test_features, test_labels)
training_time = time.time() - start_time
print(score)
print(training_time)
# Out:
# 0.45757441137272326
# 0.0033721923828125
