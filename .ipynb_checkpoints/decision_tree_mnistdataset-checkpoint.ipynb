# %%
import numpy as np
import struct
from array import array
import os
from os.path  import join
import random as rn
from sklearn import tree
import graphviz
import pydotplus
from IPython.display import Image
from io import StringIO
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import learning_curve
import time

# %%
"""
Got this code from https://www.kaggle.com/code/hojjatk/read-mnist-dataset/notebook for 
instructions on how to load data from the MNIST dataset
"""
class MnistDataloader(object):
    def __init__(self, training_images_filepath,training_labels_filepath,
                 test_images_filepath, test_labels_filepath):
        self.training_images_filepath = training_images_filepath
        self.training_labels_filepath = training_labels_filepath
        self.test_images_filepath = test_images_filepath
        self.test_labels_filepath = test_labels_filepath
    
    def read_images_labels(self, images_filepath, labels_filepath):        
        labels = []
        with open(labels_filepath, 'rb') as file:
            magic, size = struct.unpack(">II", file.read(8))
            if magic != 2049:
                raise ValueError('Magic number mismatch, expected 2049, got {}'.format(magic))
            labels = array("B", file.read())        
        
        with open(images_filepath, 'rb') as file:
            magic, size, rows, cols = struct.unpack(">IIII", file.read(16))
            if magic != 2051:
                raise ValueError('Magic number mismatch, expected 2051, got {}'.format(magic))
            image_data = array("B", file.read())        
        images = []
        for i in range(size):
            images.append([0] * rows * cols)
        for i in range(size):
            img = np.array(image_data[i * rows * cols:(i + 1) * rows * cols])
#             img = img.reshape(28, 28)
            images[i][:] = img            
        
        return np.array(images), np.array(labels)
            
    def load_data(self):
        x_train, y_train = self.read_images_labels(self.training_images_filepath, self.training_labels_filepath)
        x_test, y_test = self.read_images_labels(self.test_images_filepath, self.test_labels_filepath)
        return (x_train, y_train),(x_test, y_test)

# %%
#
# Verify Reading Dataset via MnistDataloader class
#
# %matplotlib inline
import random
import matplotlib.pyplot as plt

#
# Set file paths based on added MNIST Datasets
#
input_path = 'data/mnist_datafolder'
training_images_filepath = join(input_path, 'train-images-idx3-ubyte/train-images-idx3-ubyte')
training_labels_filepath = join(input_path, 'train-labels-idx1-ubyte/train-labels-idx1-ubyte')
test_images_filepath = join(input_path, 't10k-images-idx3-ubyte/t10k-images-idx3-ubyte')
test_labels_filepath = join(input_path, 't10k-labels-idx1-ubyte/t10k-labels-idx1-ubyte')

#
# Helper function to show a list of images with their relating titles
#
def show_images(images, title_texts):
    cols = 5
    rows = int(len(images)/cols) + 1
    plt.figure(figsize=(30,20))
    index = 1    
    for x in zip(images, title_texts):        
        image = x[0]        
        title_text = x[1]
        plt.subplot(rows, cols, index)        
        plt.imshow(image, cmap=plt.cm.gray)
        if (title_text != ''):
            plt.title(title_text, fontsize = 15);        
        index += 1

#
# Load MINST dataset
#
mnist_dataloader = MnistDataloader(training_images_filepath, training_labels_filepath, test_images_filepath, test_labels_filepath)
(x_train, y_train), (x_test, y_test) = mnist_dataloader.load_data()

# %%
"""
Setting up seed values for reproducability
"""
seed = 1234
np.random.seed(seed)
rn.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)

# %%
"""
Getting the size values for the training and testing dataset
"""
size_train_samples = np.shape(x_train)[0]
size_test_samples = np.shape(x_test)[0]

# %%
"""
This is to split up the data into sets where the size of the training data across iterations
increases by a certain percentage.
This is to prep the data for the Learning Curve Visualization
"""
learning_percentages_train_list = []
learning_percentages_label_list = []
for i in (np.logspace(-1, 1.0, 20, base=10.0) / 10):
    random_indexes = np.random.choice(size_train_samples, int(i * size_train_samples), replace = False)
    learning_percentages_train_list.append(np.take(x_train, random_indexes, axis=0))
    learning_percentages_label_list.append(np.take(y_train, random_indexes))

# %%
"""
Actually training the Decision Tree Classifier to generate the graph for the learning graph visualizer.
This should utilize the percentage of samples lists that use randomly selected samples of the
overall training data. This is so that we can test the accuracy (using cross-validation) across different
training data size samples to see at what point the accuracy score stops being affected by the size of the training
samples. This is also to see at what point the data might start getting overfit.
"""
# Defining hyperparameters here
max_depth = None
max_leaf_nodes = None
min_samples_split = 2
criterion = "entropy"

# lists to hold the results of training / validation scores
x_axis_list = []
avg_train_scores_list = []
avg_validation_scores_list = []

# First declaring the Decision Tree Classifer from scikit-learn
clf = tree.DecisionTreeClassifier(
    criterion=criterion,
    max_depth=max_depth,
    random_state=seed
)

# Main loop for the training based on different training sample sizes
for i in range(0, len(learning_percentages_train_list)):
    scores = cross_validate(
        clf,
        learning_percentages_train_list[i],
        learning_percentages_label_list[i],
        scoring="accuracy",
        return_train_score=True,
        cv=5,
        n_jobs=10,
    )
    
    avg_train_scores = np.average(scores['train_score'])
    avg_validation_scores = np.average(scores['test_score'])
    
    x_axis_list.append(len(learning_percentages_train_list[i]))
    avg_train_scores_list.append(avg_train_scores)
    avg_validation_scores_list.append(avg_validation_scores)
    
    print("=============================================")
    print("Run for " + str(len(learning_percentages_train_list[i])) + " size")
    print("Average Training Score: " + str(avg_train_scores))
    print("Average Validation Score: " + str(avg_validation_scores))
    print("=============================================")
# Out:
# =============================================
# Run for 600 size
# Average Training Score: 1.0
# Average Validation Score: 0.6233333333333334
# =============================================
# =============================================
# Run for 764 size
# Average Training Score: 1.0
# Average Validation Score: 0.6439370485036119
# =============================================
# =============================================
# Run for 974 size
# Average Training Score: 1.0
# Average Validation Score: 0.6313877874702617
# =============================================
# =============================================
# Run for 1241 size
# Average Training Score: 1.0
# Average Validation Score: 0.6914367146003368
# =============================================
# =============================================
# Run for 1581 size
# Average Training Score: 1.0
# Average Validation Score: 0.6875633909675358
# =============================================
# =============================================
# Run for 2015 size
# Average Training Score: 1.0
# Average Validation Score: 0.7260545905707195
# =============================================
# =============================================
# Run for 2568 size
# Average Training Score: 1.0
# Average Validation Score: 0.75583619663079
# =============================================
# =============================================
# Run for 3273 size
# Average Training Score: 1.0
# Average Validation Score: 0.7546550878913089
# =============================================
# =============================================
# Run for 4171 size
# Average Training Score: 1.0
# Average Validation Score: 0.7540125504386909
# =============================================
# =============================================
# Run for 5315 size
# Average Training Score: 1.0
# Average Validation Score: 0.7650047036688619
# =============================================
# =============================================
# Run for 6773 size
# Average Training Score: 1.0
# Average Validation Score: 0.7850273891217494
# =============================================
# =============================================
# Run for 8630 size
# Average Training Score: 1.0
# Average Validation Score: 0.801853997682503
# =============================================
# =============================================
# Run for 10997 size
# Average Training Score: 1.0
# Average Validation Score: 0.8091295216834098
# =============================================
# =============================================
# Run for 14014 size
# Average Training Score: 1.0
# Average Validation Score: 0.8196092541818786
# =============================================
# =============================================
# Run for 17858 size
# Average Training Score: 1.0
# Average Validation Score: 0.8346958969902817
# =============================================
# =============================================
# Run for 22756 size
# Average Training Score: 1.0
# Average Validation Score: 0.8454472046739182
# =============================================
# =============================================
# Run for 28997 size
# Average Training Score: 1.0
# Average Validation Score: 0.8497084396239541
# =============================================
# =============================================
# Run for 36950 size
# Average Training Score: 1.0
# Average Validation Score: 0.8584573748308525
# =============================================
# =============================================
# Run for 47085 size
# Average Training Score: 1.0
# Average Validation Score: 0.8684294361261549
# =============================================
# =============================================
# Run for 60000 size
# Average Training Score: 1.0
# Average Validation Score: 0.876
# =============================================

# %%
"""
Plotting the results into a learning curve graph
"""

# Plotting the training scores
plt.plot(
    x_axis_list,
    avg_train_scores_list,
    color="red",
    linewidth=3,
    marker='o',
    label = "Average Training Scores"
)

# Plotting the validation scores
plt.plot(
    x_axis_list,
    avg_validation_scores_list,
    color="orange",
    linewidth=3,
    marker='o',
    label = "Average Validation Scores"
)

# Naming X-Axis
plt.xlabel('Dataset Sizes')
# Naming Y-Axis
plt.ylabel('Accuracy scores as a percentage')
# Naming Title
plt.title("Learning Curve Graph using Cross-Validation on MNIST Dataset: Decision Trees")

plt.legend()

plt.show()

# %%
"""
Training the Decision Tree based off of the first Hyperparameter: max_depth
Building a validation curve out of this to see how the hyperparameter affects the training.
"""
# Defining hyperparameters here
max_leaf_nodes = None
min_samples_split = 2
criterion = "entropy"
max_depth_lower_limit = 1
max_depth_upper_limit = 25 # It seems that around 15, the model doesn't get better

# lists to hold the results of training / validation scores
x_axis_list = []
avg_train_scores_list = []
avg_validation_scores_list = []

# Main loop for the training based on different training sample sizes
for i in range(max_depth_lower_limit, max_depth_upper_limit + 1):
    # First declaring the Decision Tree Classifer from scikit-learn
    clf = tree.DecisionTreeClassifier(
        criterion=criterion,
        max_depth=i,
        random_state=seed
    )
    
    scores = cross_validate(
        clf,
        x_train,
        y_train,
        scoring="accuracy",
        return_train_score=True,
        cv=5,
        n_jobs=4,
    )
    
    avg_train_scores = np.average(scores['train_score'])
    avg_validation_scores = np.average(scores['test_score'])
    
    x_axis_list.append(i)
    avg_train_scores_list.append(avg_train_scores)
    avg_validation_scores_list.append(avg_validation_scores)
    
    print("=============================================")
    print("Run for " + str(i) + " max_depth")
    print("Average Training Score: " + str(avg_train_scores))
    print("Average Validation Score: " + str(avg_validation_scores))
    print("=============================================")
# Out:
# =============================================
# Run for 1 max_depth
# Average Training Score: 0.20121666666666665
# Average Validation Score: 0.19946666666666665
# =============================================
# =============================================
# Run for 2 max_depth
# Average Training Score: 0.3352333333333334
# Average Validation Score: 0.3322666666666666
# =============================================
# =============================================
# Run for 3 max_depth
# Average Training Score: 0.49031250000000004
# Average Validation Score: 0.4885333333333334
# =============================================
# =============================================
# Run for 4 max_depth
# Average Training Score: 0.6098958333333333
# Average Validation Score: 0.6049666666666667
# =============================================
# =============================================
# Run for 5 max_depth
# Average Training Score: 0.6967916666666667
# Average Validation Score: 0.68945
# =============================================
# =============================================
# Run for 6 max_depth
# Average Training Score: 0.7572458333333334
# Average Validation Score: 0.7483000000000001
# =============================================
# =============================================
# Run for 7 max_depth
# Average Training Score: 0.8021708333333335
# Average Validation Score: 0.7885166666666666
# =============================================
# =============================================
# Run for 8 max_depth
# Average Training Score: 0.8467416666666667
# Average Validation Score: 0.8248999999999999
# =============================================
# =============================================
# Run for 9 max_depth
# Average Training Score: 0.88455
# Average Validation Score: 0.8482833333333334
# =============================================
# =============================================
# Run for 10 max_depth
# Average Training Score: 0.918925
# Average Validation Score: 0.8631333333333332
# =============================================
# =============================================
# Run for 11 max_depth
# Average Training Score: 0.9483041666666667
# Average Validation Score: 0.8692666666666667
# =============================================
# =============================================
# Run for 12 max_depth
# Average Training Score: 0.9705791666666667
# Average Validation Score: 0.8726166666666668
# =============================================
# =============================================
# Run for 13 max_depth
# Average Training Score: 0.9848208333333334
# Average Validation Score: 0.8726166666666668
# =============================================
# =============================================
# Run for 14 max_depth
# Average Training Score: 0.992275
# Average Validation Score: 0.8733333333333333
# =============================================
# =============================================
# Run for 15 max_depth
# Average Training Score: 0.9959166666666667
# Average Validation Score: 0.87375
# =============================================
# =============================================
# Run for 16 max_depth
# Average Training Score: 0.9979291666666666
# Average Validation Score: 0.8734666666666666
# =============================================
# =============================================
# Run for 17 max_depth
# Average Training Score: 0.9989583333333332
# Average Validation Score: 0.8736666666666666
# =============================================
# =============================================
# Run for 18 max_depth
# Average Training Score: 0.9994541666666666
# Average Validation Score: 0.8728666666666667
# =============================================
# =============================================
# Run for 19 max_depth
# Average Training Score: 0.9996958333333333
# Average Validation Score: 0.8732666666666666
# =============================================
# =============================================
# Run for 20 max_depth
# Average Training Score: 0.9998583333333333
# Average Validation Score: 0.8732833333333332
# =============================================
# =============================================
# Run for 21 max_depth
# Average Training Score: 0.9999333333333335
# Average Validation Score: 0.8723333333333334
# =============================================
# =============================================
# Run for 22 max_depth
# Average Training Score: 0.9999750000000001
# Average Validation Score: 0.8735666666666665
# =============================================
# =============================================
# Run for 23 max_depth
# Average Training Score: 0.9999958333333334
# Average Validation Score: 0.8731666666666668
# =============================================
# =============================================
# Run for 24 max_depth
# Average Training Score: 1.0
# Average Validation Score: 0.8735166666666666
# =============================================
# =============================================
# Run for 25 max_depth
# Average Training Score: 1.0
# Average Validation Score: 0.8735166666666666
# =============================================

# %%
"""
Plotting the results into a validation curve graph
"""

# Plotting the training scores
plt.plot(
    x_axis_list,
    avg_train_scores_list,
    color="blue",
    linewidth=3,
    marker='o',
    label = "Average Training Scores"
)

# Plotting the validation scores
plt.plot(
    x_axis_list,
    avg_validation_scores_list,
    color="purple",
    linewidth=3,
    marker='o',
    label = "Average Validation Scores"
)

# Naming X-Axis
plt.xlabel('Max_Depth')
# Naming Y-Axis
plt.ylabel('Accuracy scores as a percentage')
# Naming Title
plt.title("Validation Curve Graph using Cross-Validation on MNIST Dataset")

plt.legend()

plt.show()

# %%
"""
Training the Decision Tree based off of the first Hyperparameter: max_leaf_nodes
Building a validation curve out of this to see how the hyperparameter affects the training.
"""
# Defining hyperparameters here
min_samples_split = 2
criterion = "entropy"
max_depth = None # It seems that around 15, the model doesn't get better
max_leaf_nodes_lower_limit = 2
max_leaf_nodes_upper_limit = 502

# lists to hold the results of training / validation scores
x_axis_list = []
avg_train_scores_list = []
avg_validation_scores_list = []

# Main loop for the training based on different training sample sizes
for i in range(max_leaf_nodes_lower_limit, max_leaf_nodes_upper_limit + 1, 10):
    # First declaring the Decision Tree Classifer from scikit-learn
    clf = tree.DecisionTreeClassifier(
        criterion=criterion,
        max_depth=max_depth,
        max_leaf_nodes=i,
        random_state=seed
    )
    
    scores = cross_validate(
        clf,
        x_train,
        y_train,
        scoring="accuracy",
        return_train_score=True,
        cv=5,
        n_jobs=4,
    )
    
    avg_train_scores = np.average(scores['train_score'])
    avg_validation_scores = np.average(scores['test_score'])
    
    x_axis_list.append(i)
    avg_train_scores_list.append(avg_train_scores)
    avg_validation_scores_list.append(avg_validation_scores)
    
    print("=============================================")
    print("Run for " + str(i) + " max_leaf_nodes")
    print("Average Training Score: " + str(avg_train_scores))
    print("Average Validation Score: " + str(avg_validation_scores))
    print("=============================================")
# Out:
# =============================================
# Run for 2 max_leaf_nodes
# Average Training Score: 0.20121666666666665
# Average Validation Score: 0.19946666666666665
# =============================================
# =============================================
# Run for 12 max_leaf_nodes
# Average Training Score: 0.5761999999999999
# Average Validation Score: 0.5721166666666667
# =============================================
# =============================================
# Run for 22 max_leaf_nodes
# Average Training Score: 0.6620708333333333
# Average Validation Score: 0.6560666666666666
# =============================================
# =============================================
# Run for 32 max_leaf_nodes
# Average Training Score: 0.7041666666666667
# Average Validation Score: 0.6963666666666667
# =============================================
# =============================================
# Run for 42 max_leaf_nodes
# Average Training Score: 0.7255499999999999
# Average Validation Score: 0.7177166666666667
# =============================================
# =============================================
# Run for 52 max_leaf_nodes
# Average Training Score: 0.7433750000000001
# Average Validation Score: 0.7359833333333332
# =============================================
# =============================================
# Run for 62 max_leaf_nodes
# Average Training Score: 0.7599208333333334
# Average Validation Score: 0.7515
# =============================================
# =============================================
# Run for 72 max_leaf_nodes
# Average Training Score: 0.772325
# Average Validation Score: 0.7618333333333333
# =============================================
# =============================================
# Run for 82 max_leaf_nodes
# Average Training Score: 0.7824916666666667
# Average Validation Score: 0.7722666666666667
# =============================================
# =============================================
# Run for 92 max_leaf_nodes
# Average Training Score: 0.7903916666666666
# Average Validation Score: 0.7790833333333333
# =============================================
# =============================================
# Run for 102 max_leaf_nodes
# Average Training Score: 0.7974208333333332
# Average Validation Score: 0.7848333333333333
# =============================================
# =============================================
# Run for 112 max_leaf_nodes
# Average Training Score: 0.8041791666666667
# Average Validation Score: 0.7917166666666667
# =============================================
# =============================================
# Run for 122 max_leaf_nodes
# Average Training Score: 0.8105791666666665
# Average Validation Score: 0.7972333333333333
# =============================================
# =============================================
# Run for 132 max_leaf_nodes
# Average Training Score: 0.8165875
# Average Validation Score: 0.8026500000000001
# =============================================
# =============================================
# Run for 142 max_leaf_nodes
# Average Training Score: 0.8220958333333334
# Average Validation Score: 0.8070833333333333
# =============================================
# =============================================
# Run for 152 max_leaf_nodes
# Average Training Score: 0.8264041666666666
# Average Validation Score: 0.8108666666666666
# =============================================
# =============================================
# Run for 162 max_leaf_nodes
# Average Training Score: 0.8310458333333333
# Average Validation Score: 0.8154833333333332
# =============================================
# =============================================
# Run for 172 max_leaf_nodes
# Average Training Score: 0.8350500000000001
# Average Validation Score: 0.8189833333333333
# =============================================
# =============================================
# Run for 182 max_leaf_nodes
# Average Training Score: 0.8385708333333334
# Average Validation Score: 0.8213666666666667
# =============================================
# =============================================
# Run for 192 max_leaf_nodes
# Average Training Score: 0.8420333333333334
# Average Validation Score: 0.8237166666666667
# =============================================
# =============================================
# Run for 202 max_leaf_nodes
# Average Training Score: 0.8455333333333334
# Average Validation Score: 0.8261333333333333
# =============================================
# =============================================
# Run for 212 max_leaf_nodes
# Average Training Score: 0.8482541666666666
# Average Validation Score: 0.8273000000000001
# =============================================
# =============================================
# Run for 222 max_leaf_nodes
# Average Training Score: 0.8514208333333333
# Average Validation Score: 0.8299999999999998
# =============================================
# =============================================
# Run for 232 max_leaf_nodes
# Average Training Score: 0.8539541666666667
# Average Validation Score: 0.8320666666666667
# =============================================
# =============================================
# Run for 242 max_leaf_nodes
# Average Training Score: 0.8567625
# Average Validation Score: 0.834
# =============================================
# =============================================
# Run for 252 max_leaf_nodes
# Average Training Score: 0.8591708333333333
# Average Validation Score: 0.8361833333333333
# =============================================
# =============================================
# Run for 262 max_leaf_nodes
# Average Training Score: 0.8616791666666668
# Average Validation Score: 0.8376333333333333
# =============================================
# =============================================
# Run for 272 max_leaf_nodes
# Average Training Score: 0.8637833333333333
# Average Validation Score: 0.8387333333333334
# =============================================
# =============================================
# Run for 282 max_leaf_nodes
# Average Training Score: 0.8657666666666666
# Average Validation Score: 0.8400000000000001
# =============================================
# =============================================
# Run for 292 max_leaf_nodes
# Average Training Score: 0.8676375000000001
# Average Validation Score: 0.84135
# =============================================
# =============================================
# Run for 302 max_leaf_nodes
# Average Training Score: 0.8696958333333333
# Average Validation Score: 0.8425166666666666
# =============================================
# =============================================
# Run for 312 max_leaf_nodes
# Average Training Score: 0.8723333333333333
# Average Validation Score: 0.8446333333333333
# =============================================
# =============================================
# Run for 322 max_leaf_nodes
# Average Training Score: 0.874
# Average Validation Score: 0.8457666666666667
# =============================================
# =============================================
# Run for 332 max_leaf_nodes
# Average Training Score: 0.8757458333333332
# Average Validation Score: 0.8466666666666667
# =============================================
# =============================================
# Run for 342 max_leaf_nodes
# Average Training Score: 0.8774583333333335
# Average Validation Score: 0.84785
# =============================================
# =============================================
# Run for 352 max_leaf_nodes
# Average Training Score: 0.8790958333333332
# Average Validation Score: 0.8492166666666666
# =============================================
# =============================================
# Run for 362 max_leaf_nodes
# Average Training Score: 0.8808791666666667
# Average Validation Score: 0.8501166666666666
# =============================================
# =============================================
# Run for 372 max_leaf_nodes
# Average Training Score: 0.8823291666666666
# Average Validation Score: 0.85075
# =============================================
# =============================================
# Run for 382 max_leaf_nodes
# Average Training Score: 0.8836541666666665
# Average Validation Score: 0.8515
# =============================================
# =============================================
# Run for 392 max_leaf_nodes
# Average Training Score: 0.8854291666666667
# Average Validation Score: 0.8524833333333334
# =============================================
# =============================================
# Run for 402 max_leaf_nodes
# Average Training Score: 0.8869541666666667
# Average Validation Score: 0.8535333333333334
# =============================================
# =============================================
# Run for 412 max_leaf_nodes
# Average Training Score: 0.8881583333333334
# Average Validation Score: 0.8545999999999999
# =============================================
# =============================================
# Run for 422 max_leaf_nodes
# Average Training Score: 0.8895916666666667
# Average Validation Score: 0.8553000000000001
# =============================================
# =============================================
# Run for 432 max_leaf_nodes
# Average Training Score: 0.8909416666666667
# Average Validation Score: 0.8560833333333333
# =============================================
# =============================================
# Run for 442 max_leaf_nodes
# Average Training Score: 0.8921374999999999
# Average Validation Score: 0.8572833333333334
# =============================================
# =============================================
# Run for 452 max_leaf_nodes
# Average Training Score: 0.8931875
# Average Validation Score: 0.85815
# =============================================
# =============================================
# Run for 462 max_leaf_nodes
# Average Training Score: 0.8943958333333333
# Average Validation Score: 0.8588833333333333
# =============================================
# =============================================
# Run for 472 max_leaf_nodes
# Average Training Score: 0.8956416666666666
# Average Validation Score: 0.8592833333333333
# =============================================
# =============================================
# Run for 482 max_leaf_nodes
# Average Training Score: 0.8968791666666667
# Average Validation Score: 0.8600833333333332
# =============================================
# =============================================
# Run for 492 max_leaf_nodes
# Average Training Score: 0.8980583333333334
# Average Validation Score: 0.8604166666666666
# =============================================
# =============================================
# Run for 502 max_leaf_nodes
# Average Training Score: 0.8991208333333335
# Average Validation Score: 0.8609833333333334
# =============================================

# %%
"""
Plotting the results into a validation curve graph
"""

# Plotting the training scores
plt.plot(
    x_axis_list,
    avg_train_scores_list,
    color="blue",
    linewidth=3,
    marker='o',
    label = "Average Training Scores"
)

# Plotting the validation scores
plt.plot(
    x_axis_list,
    avg_validation_scores_list,
    color="purple",
    linewidth=3,
    marker='o',
    label = "Average Validation Scores"
)

# Naming X-Axis
plt.xlabel('Max Leaf Nodes')
# Naming Y-Axis
plt.ylabel('Accuracy scores as a percentage')
# Naming Title
plt.title("Validation Curve Graph using Cross-Validation on MNIST Dataset")

plt.legend()

plt.show()

# %%
"""
Training the Decision Tree based off of the first Hyperparameter: min_samples_split
Building a validation curve out of this to see how the hyperparameter affects the training.
"""
# Defining hyperparameters here
max_leaf_nodes = None # seems that 600 max leaf nodes is the best
criterion = "entropy"
max_depth = None # It seems that around 15, the model doesn't get better
min_samples_split_lower_limit = 2
min_samples_split_nodes_upper_limit = 102

# lists to hold the results of training / validation scores
x_axis_list = []
avg_train_scores_list = []
avg_validation_scores_list = []

# Main loop for the training based on different training sample sizes
for i in range(min_samples_split_lower_limit, min_samples_split_nodes_upper_limit + 1, 5):
    # First declaring the Decision Tree Classifer from scikit-learn
    clf = tree.DecisionTreeClassifier(
        criterion=criterion,
        max_depth=max_depth,
        max_leaf_nodes=max_leaf_nodes,
        min_samples_split=i,
        random_state=seed
    )
    
    scores = cross_validate(
        clf,
        x_train,
        y_train,
        scoring="accuracy",
        return_train_score=True,
        cv=5,
        n_jobs=4,
    )
    
    avg_train_scores = np.average(scores['train_score'])
    avg_validation_scores = np.average(scores['test_score'])
    
    x_axis_list.append(i)
    avg_train_scores_list.append(avg_train_scores)
    avg_validation_scores_list.append(avg_validation_scores)
    
    print("=============================================")
    print("Run for " + str(i) + " min_samples_split")
    print("Average Training Score: " + str(avg_train_scores))
    print("Average Validation Score: " + str(avg_validation_scores))
    print("=============================================")
# Out:
# =============================================
# Run for 2 min_samples_split
# Average Training Score: 1.0
# Average Validation Score: 0.8735166666666666
# =============================================
# =============================================
# Run for 7 min_samples_split
# Average Training Score: 0.9792333333333332
# Average Validation Score: 0.8718333333333333
# =============================================
# =============================================
# Run for 12 min_samples_split
# Average Training Score: 0.9638249999999999
# Average Validation Score: 0.8718666666666666
# =============================================
# =============================================
# Run for 17 min_samples_split
# Average Training Score: 0.9506666666666665
# Average Validation Score: 0.8710666666666667
# =============================================
# =============================================
# Run for 22 min_samples_split
# Average Training Score: 0.9408541666666668
# Average Validation Score: 0.86955
# =============================================
# =============================================
# Run for 27 min_samples_split
# Average Training Score: 0.9320375000000001
# Average Validation Score: 0.8664166666666666
# =============================================
# =============================================
# Run for 32 min_samples_split
# Average Training Score: 0.9249499999999999
# Average Validation Score: 0.8641
# =============================================
# =============================================
# Run for 37 min_samples_split
# Average Training Score: 0.9188041666666666
# Average Validation Score: 0.8625833333333335
# =============================================
# =============================================
# Run for 42 min_samples_split
# Average Training Score: 0.9133583333333334
# Average Validation Score: 0.8612333333333334
# =============================================
# =============================================
# Run for 47 min_samples_split
# Average Training Score: 0.9084958333333333
# Average Validation Score: 0.8593666666666667
# =============================================
# =============================================
# Run for 52 min_samples_split
# Average Training Score: 0.9046083333333333
# Average Validation Score: 0.8580333333333334
# =============================================
# =============================================
# Run for 57 min_samples_split
# Average Training Score: 0.9002708333333335
# Average Validation Score: 0.8561833333333334
# =============================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/2t/729mx8852z76pxc60kfsnx3r0000gn/T/ipykernel_84859/3516510923.py in <module>
#      33         return_train_score=True,
#      34         cv=5,
# ---> 35         n_jobs=4,
#      36     )
#      37
#
# ~/miniconda3/envs/ai_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     281             error_score=error_score,
#     282         )
# --> 283         for train, test in cv.split(X, y, groups)
#     284     )
#     285
#
# ~/miniconda3/envs/ai_env/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1096
#    1097             with self._backend.retrieval_context():
# -> 1098                 self.retrieve()
#    1099             # Make sure that we get a last message telling us we are done
#    1100             elapsed_time = time.time() - self._start_time
#
# ~/miniconda3/envs/ai_env/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     973             try:
#     974                 if getattr(self._backend, 'supports_timeout', False):
# --> 975                     self._output.extend(job.get(timeout=self.timeout))
#     976                 else:
#     977                     self._output.extend(job.get())
#
# ~/miniconda3/envs/ai_env/lib/python3.7/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     565         AsyncResults.get from multiprocessing."""
#     566         try:
# --> 567             return future.result(timeout=timeout)
#     568         except CfTimeoutError as e:
#     569             raise TimeoutError from e
#
# ~/miniconda3/envs/ai_env/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     428                 return self.__get_result()
#     429
# --> 430             self._condition.wait(timeout)
#     431
#     432             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/miniconda3/envs/ai_env/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
"""
Plotting the results into a validation curve graph
"""

# Plotting the training scores
plt.plot(
    x_axis_list,
    avg_train_scores_list,
    color="blue",
    linewidth=3,
    marker='o',
    label = "Average Training Scores"
)

# Plotting the validation scores
plt.plot(
    x_axis_list,
    avg_validation_scores_list,
    color="purple",
    linewidth=3,
    marker='o',
    label = "Average Validation Scores"
)

# Naming X-Axis
plt.xlabel('Min Samples Split')
# Naming Y-Axis
plt.ylabel('Accuracy scores as a percentage')
# Naming Title
plt.title("Validation Curve Graph using Cross-Validation on Music Genre Dataset")

plt.legend()

plt.show()

# %%
"""
Final results for the DecisionTreeClassifier using the optimized values for hyper parameters
"""
# Defining hyperparameters here
max_depth = 15
max_leaf_nodes = 300
min_samples_split = 80
criterion = "entropy"

# lists to hold the results of training / validation scores
x_axis_list = []
avg_train_scores_list = []
avg_validation_scores_list = []
iteration_wall_clock_list = []

# First declaring the Decision Tree Classifer from scikit-learn
clf = tree.DecisionTreeClassifier(
    criterion=criterion,
    max_depth=max_depth,
    random_state=seed
)

# Main loop for the training based on different training sample sizes
for i in range(0, len(learning_percentages_train_list)):
    start_time = time.time()
    scores = cross_validate(
        clf,
        learning_percentages_train_list[i],
        learning_percentages_label_list[i],
        scoring="accuracy",
        return_train_score=True,
        cv=5,
        n_jobs=10,
    )
    training_time = time.time() - start_time
    
    avg_train_scores = np.average(scores['train_score'])
    avg_validation_scores = np.average(scores['test_score'])
    
    x_axis_list.append(len(learning_percentages_train_list[i]))
    avg_train_scores_list.append(avg_train_scores)
    avg_validation_scores_list.append(avg_validation_scores)
    iteration_wall_clock_list.append(training_time)
    
    print("=============================================")
    print("Run for " + str(len(learning_percentages_train_list[i])) + " size")
    print("Average Training Score: " + str(avg_train_scores))
    print("Average Validation Score: " + str(avg_validation_scores))
    print("Training Time: " + str(training_time))
    print("=============================================")
# Out:
# =============================================
# Run for 600 size
# Average Training Score: 1.0
# Average Validation Score: 0.6233333333333334
# Training Time: 1.3221070766448975
# =============================================
# =============================================
# Run for 764 size
# Average Training Score: 1.0
# Average Validation Score: 0.6439370485036119
# Training Time: 0.4734840393066406
# =============================================
# =============================================
# Run for 974 size
# Average Training Score: 1.0
# Average Validation Score: 0.6313877874702617
# Training Time: 0.4976792335510254
# =============================================
# =============================================
# Run for 1241 size
# Average Training Score: 1.0
# Average Validation Score: 0.6914367146003368
# Training Time: 0.5437493324279785
# =============================================
# =============================================
# Run for 1581 size
# Average Training Score: 1.0
# Average Validation Score: 0.6875633909675358
# Training Time: 0.3359980583190918
# =============================================
# =============================================
# Run for 2015 size
# Average Training Score: 1.0
# Average Validation Score: 0.7260545905707195
# Training Time: 0.41782712936401367
# =============================================
# =============================================
# Run for 2568 size
# Average Training Score: 1.0
# Average Validation Score: 0.75583619663079
# Training Time: 0.48906397819519043
# =============================================
# =============================================
# Run for 3273 size
# Average Training Score: 1.0
# Average Validation Score: 0.7546550878913089
# Training Time: 0.5330009460449219
# =============================================
# =============================================
# Run for 4171 size
# Average Training Score: 1.0
# Average Validation Score: 0.7540125504386909
# Training Time: 0.7188720703125
# =============================================
# =============================================
# Run for 5315 size
# Average Training Score: 1.0
# Average Validation Score: 0.7650047036688619
# Training Time: 0.8668727874755859
# =============================================
# =============================================
# Run for 6773 size
# Average Training Score: 1.0
# Average Validation Score: 0.7850273891217494
# Training Time: 1.4777181148529053
# =============================================
# =============================================
# Run for 8630 size
# Average Training Score: 1.0
# Average Validation Score: 0.801853997682503
# Training Time: 1.8407680988311768
# =============================================
# =============================================
# Run for 10997 size
# Average Training Score: 0.9999318026824277
# Average Validation Score: 0.807674314771177
# Training Time: 2.2984602451324463
# =============================================
# =============================================
# Run for 14014 size
# Average Training Score: 0.999125871260748
# Average Validation Score: 0.8183960134484236
# Training Time: 2.8550021648406982
# =============================================
# =============================================
# Run for 17858 size
# Average Training Score: 0.9989360457768797
# Average Validation Score: 0.8358720067684718
# Training Time: 3.4425339698791504
# =============================================
# =============================================
# Run for 22756 size
# Average Training Score: 0.9987475799162484
# Average Validation Score: 0.8443046565790789
# Training Time: 3.824871301651001
# =============================================
# =============================================
# Run for 28997 size
# Average Training Score: 0.9983877634330998
# Average Validation Score: 0.8518122030552236
# Training Time: 4.82906174659729
# =============================================
# =============================================
# Run for 36950 size
# Average Training Score: 0.9983152909336942
# Average Validation Score: 0.858105548037889
# Training Time: 5.658929824829102
# =============================================
# =============================================
# Run for 47085 size
# Average Training Score: 0.99750451311458
# Average Validation Score: 0.8689603907826271
# Training Time: 7.944120168685913
# =============================================
# =============================================
# Run for 60000 size
# Average Training Score: 0.9961166666666668
# Average Validation Score: 0.8761666666666666
# Training Time: 9.62967562675476
# =============================================

# %%
"""
Plotting the results into a learning curve graph
"""

# Plotting the training scores
plt.plot(
    x_axis_list,
    avg_train_scores_list,
    color="red",
    linewidth=3,
    marker='o',
    label = "Average Training Scores"
)

# Plotting the validation scores
plt.plot(
    x_axis_list,
    avg_validation_scores_list,
    color="orange",
    linewidth=3,
    marker='o',
    label = "Average Validation Scores"
)

# Naming X-Axis
plt.xlabel('Dataset Sizes')
# Naming Y-Axis
plt.ylabel('Accuracy scores as a percentage')
# Naming Title
plt.title("Learning Curve Graph using Cross-Validation on MNIST Dataset: Decision Trees")

plt.legend()

plt.show()

# %%
"""
Plotting the results into a learning curve graph
"""

# Plotting the training scores
plt.plot(
    x_axis_list,
    iteration_wall_clock_list,
    color="red",
    linewidth=3,
    marker='o',
    label = "Average Training Scores"
)

# Naming X-Axis
plt.xlabel('Dataset Sizes')
# Naming Y-Axis
plt.ylabel('Wall Clock Times')
# Naming Title
plt.title("Performance Curve Graph using Cross-Validation on MNIST Dataset: Decision Trees")

plt.legend()

plt.show()

# %%
clf.fit(x_train, y_train)
start_time = time.time()
score = clf.score(x_test, y_test)
training_time = time.time() - start_time
print(score)
print(training_time)
# Out:
# 0.8855
# 0.020296812057495117

# %%
dot_data = StringIO()
tree.export_graphviz(clf, out_file=dot_data, filled=True, rounded=True, special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %%
dot_data = tree.export_graphviz(clf, out_file=None, filled=True, rounded=True, special_characters=True)
graph = graphviz.Source(dot_data)
graph.render("mnist")
# Out:
# 'mnist.pdf'
